# %%
import numpy as np
import matplotlib.pyplot as plt
import sympy
import math
from sympy import init_printing
import scipy.stats as stats
init_printing()

# %%
from sympy.abc import theta
from sympy.abc import pi
from sympy.abc import sigma
from sympy.abc import mu
init_printing(use_unicode=True)

# %%
z = sympy.sin(theta**2)
result = z
result
z1 = z.subs(theta,1)
z1
# Out:
# sin(1)

# %%
for i in range (5):
    z1 = z.subs(theta,i)
    print(z1)
# Out:
# 0
# sin(1)
# sin(4)
# sin(9)
# sin(16)

# %%
m = sympy.symbols('m')
x = sympy.symbols('x')
part1 = sympy.symbols('part1')
part2 = sympy.symbols('part2')
part3 = sympy.symbols('part3')
part4 = sympy.symbols('part4')

# %%
part1 = (1/(m-1)**0.5)

part2 = (sympy.gamma(m/2))/(sympy.gamma((m-1)/2)*sympy.gamma(1/2))

part3 = 2/(1-((x**2)/(m-1)))

part4 = (1-(x**2/(m-1)))**((m-1)/2)

# %%
f2 = (1/2)*((1/(m-1)**0.5))*((sympy.gamma(m/2))/(sympy.gamma((m-1)/2)*sympy.gamma(1/2)))*(2/(1-((x**2)/(m-1))))*((1-(x**2/(m-1)))**((m-1)/2))
f2
# Out:
#                                            m   1
#                                            ─ - ─
#                                            2   2
#                               ⎛     2     ⎞
#                          -0.5 ⎜    x      ⎟       ⎛m⎞
# 0.564189583547756⋅(m - 1)    ⋅⎜- ───── + 1⎟     ⋅Γ⎜─⎟
#                               ⎝  m - 1    ⎠       ⎝2⎠
# ─────────────────────────────────────────────────────
#                 ⎛     2     ⎞
#                 ⎜    x      ⎟  ⎛m   1⎞
#                 ⎜- ───── + 1⎟⋅Γ⎜─ - ─⎟
#                 ⎝  m - 1    ⎠  ⎝2   2⎠

# %%
part2 = (sympy.gamma(m/2))/((sympy.gamma((m-1)/2))*(sympy.gamma(1/2)))
part2
# Out:
#                    ⎛m⎞
# 0.564189583547756⋅Γ⎜─⎟
#                    ⎝2⎠
# ──────────────────────
#         ⎛m   1⎞
#        Γ⎜─ - ─⎟
#         ⎝2   2⎠

# %%
part3
# Out:
#      2
# ───────────
#      2
#     x
# - ───── + 1
#   m - 1

# %%
f2
# Out:
#                                           m   1
#                                           ─ - ─
#                                           2   2
#                              ⎛     2     ⎞
#                         -0.5 ⎜    x      ⎟       ⎛m⎞
# 1.12837916709551⋅(m - 1)    ⋅⎜- ───── + 1⎟     ⋅Γ⎜─⎟
#                              ⎝  m - 1    ⎠       ⎝2⎠
# ────────────────────────────────────────────────────
#                ⎛     2     ⎞
#                ⎜    x      ⎟  ⎛m   1⎞
#                ⎜- ───── + 1⎟⋅Γ⎜─ - ─⎟
#                ⎝  m - 1    ⎠  ⎝2   2⎠

# %%
f3= f2.subs(m,29)
f3
# Out:
#                              13
#                      ⎛     2⎞
#                      ⎜    x ⎟
# 0.446157624244232⋅√π⋅⎜1 - ──⎟
#                      ⎝    28⎠

# %%
results = []
x_value = []
for i in np.arange (-5.29,5.29,10.58/100):
        f3 = f2.subs([(m,29),(x,i)])
        results.append(f3)
        x_value.append(i)

# %%
plt.figure()
plt.plot(x_value,results)
plt.show()

# %%
f3= f2.subs(m,2)
f3
# Out:
# 1.12837916709551
# ────────────────
#        ________
#       ╱      2
#  √π⋅╲╱  1 - x

# %%
results = []
x_value = []
for i in np.arange (-1,1,2/100):
    if i == -1 :
        pass
    else:
        f3 = f2.subs([(m,2),(x,i)])
        results.append(f3)
        x_value.append(i)

# %%
plt.figure()
plt.plot(x_value,results)
plt.show()

# %%
f3= f2.subs(m,10)
f3
# Out:
#                          7/2
#                  ⎛     2⎞
#                  ⎜    x ⎟
# 1.37554793703072⋅⎜1 - ──⎟
#                  ⎝    9 ⎠
# ────────────────────────────
#              √π

# %%
results = []
x_value = []
for i in np.arange (-3,3,6/100):
    if i == -3 :
        pass
    else:
        f3 = f2.subs([(m,10),(x,i)])
        results.append(f3)
        x_value.append(i)

# %%
plt.figure()
plt.plot(x_value,results)
plt.show()

# %%
f3= f2.subs(m,4)
f3
# Out:
#                       ________
#                      ╱      2
#                     ╱      x
# 1.30294003174112⋅  ╱   1 - ──
#                  ╲╱        3
# ──────────────────────────────
#               √π

# %%
results = []
x_value = []
for i in np.arange (-1.73,1.73,3.46/100):
        f3 = f2.subs([(m,4),(x,i)])
        results.append(f3)
        x_value.append(i)

# %%
plt.figure()
plt.plot(x_value,results)
plt.show()

# %%
f3= f2.subs(m,3)
f3
# Out:
# 0.398942280401433⋅√π

# %%
for u in range(50,100) :
    results = []
    x_value = []
    for i in np.arange (-(u-1)**0.5,(u-1)**0.5,(((u-1)**0.5)*2)/100):
        if i == -(u-1)**0.5:
            pass
        else:
            f3 = f2.subs([(m,u),(x,i)])
            results.append(f3)
            x_value.append(i)  
    plt.figure()
    plt.plot(x_value,results)
    plt.xlabel(u)
    plt.show()

# %%
results2 = []
x_value2 = []
for i in np.arange (-(2-1)**0.5,(2-1)**0.5,(((2-1)**0.5)*2)/100):
    if i == -(2-1)**0.5:
        pass
    else:
        f3 = f2.subs([(m,2),(x,i)])
        results2.append(f3)
        x_value2.append(i)

# %%
results3 = []
x_value3 = []
for i in np.arange (-(3-1)**0.5,(3-1)**0.5,(((3-1)**0.5)*2)/100):
    if i == -(3-1)**0.5:
        pass
    else:
        f3 = f2.subs([(m,3),(x,i)])
        results3.append(f3)
        x_value3.append(i)

# %%
results4 = []
x_value4 = []
for i in np.arange (-(4-1)**0.5,(4-1)**0.5,(((4-1)**0.5)*2)/100):
    if i == -(4-1)**0.5:
        pass
    else:
        f3 = f2.subs([(m,4),(x,i)])
        results4.append(f3)
        x_value4.append(i)

# %%
results10 = []
x_value10 = []
for i in np.arange (-(10-1)**0.5,(10-1)**0.5,(((10-1)**0.5)*2)/100):
    if i == -(10-1)**0.5:
        pass
    else:
        f3 = f2.subs([(m,10),(x,i)])
        results10.append(f3)
        x_value10.append(i)

# %%
results29 = []
x_value29 = []
for i in np.arange (-(29-1)**0.5,(29-1)**0.5,(((29-1)**0.5)*2)/100):
    if i == -(29-1)**0.5:
        pass
    else:
        f3 = f2.subs([(m,29),(x,i)])
        results29.append(f3)
        x_value29.append(i)

# %%
results100 = []
x_value100 = []
for i in np.arange (-(100-1)**0.5,(100-1)**0.5,(((100-1)**0.5)*2)/100):
    if i == -(100-1)**0.5:
        pass
    else:
        f3 = f2.subs([(m,100),(x,i)])
        results100.append(f3)
        x_value100.append(i)

# %%
mu = 0
variance = 1
sigma = math.sqrt(variance)
x = np.linspace(mu - 3*sigma, mu + 3*sigma, 100)
plt.plot(x, stats.norm.pdf(x, mu, sigma))
plt.show()

# %%
plt.figure(figsize=(12,5))
plt.plot(x_value2,results2,label="m=2")
plt.plot(x_value3,results3,label="m=3")
plt.plot(x_value4,results4,label="m=4")
plt.plot(x_value10,results10,label="m=10")
plt.plot(x_value29,results29,label="m=29")
#plt.plot(x_value100,results100,label="m=100")
plt.plot(x, stats.norm.pdf(x, mu, sigma),dashes=[6,2],label="normal distribution")
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
